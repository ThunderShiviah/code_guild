# %% [markdown]
# # wk2.1 Creating HTML in style: CSS

# %% [markdown]
# # First, some more on HTML
#
# ## Forms
#
# ### ```<form>```
# #### ```action```
# #### ```method```
#
# * Either get or post
# * get returns results in the URL (insecure).
# * post returns results in the metadata of the http response (more secure)

# %%
import requests
#r = requests.get('https://api.github.com/events')
r = 
r.text
# Out:
# '[{"id":"3191471084","type":"PushEvent","actor":{"id":4111401,"login":"timvideos-robot","gravatar_id":"","url":"https://api.github.com/users/timvideos-robot","avatar_url":"https://avatars.githubusercontent.com/u/4111401?"},"repo":{"id":8867721,"name":"timvideos/getting-started","url":"https://api.github.com/repos/timvideos/getting-started"},"payload":{"push_id":809239311,"size":1,"distinct_size":1,"ref":"refs/heads/keepalive","head":"a66209993d53f63cfd682c3e70f527db76a74dc4","before":"e0206a7f1237c21b9d44e930d8da7474e4a3c6be","commits":[{"sha":"a66209993d53f63cfd682c3e70f527db76a74dc4","author":{"email":"robot@timvideos.us","name":"TimVideos.us Robot"},"message":"Daily commit on 20150929-170001 to keep getting-started at top of github.","distinct":true,"url":"https://api.github.com/repos/timvideos/getting-started/commits/a66209993d53f63cfd682c3e70f527db76a74dc4"}]},"public":true,"created_at":"2015-09-29T16:58:33Z","org":{"id":811205,"login":"timvideos","gravatar_id":"","url":"https://api.github.com/orgs/timvideos","avatar_url":"https://avatars.githubusercontent.com/u/811205?"}},{"id":"3191471075","type":"WatchEvent","actor":{"id":2207203,"login":"tifletcher","gravatar_id":"","url":"https://api.github.com/users/tifletcher","avatar_url":"https://avatars.githubusercontent.com/u/2207203?"},"repo":{"id":26316966,"name":"cyclejs/cycle-core","url":"https://api.github.com/repos/cyclejs/cycle-core"},"payload":{"action":"started"},"public":true,"created_at":"2015-09-29T16:58:33Z","org":{"id":12686838,"login":"cyclejs","gravatar_id":"","url":"https://api.github.com/orgs/cyclejs","avatar_url":"https://avatars.githubusercontent.com/u/12686838?"}},{"id":"3191471072","type":"DeleteEvent","actor":{"id":8457307,"login":"lorengordon","gravatar_id":"","url":"https://api.github.com/users/lorengordon","avatar_url":"https://avatars.githubusercontent.com/u/8457307?"},"repo":{"id":38041591,"name":"lorengordon/cfn","url":"https://api.github.com/repos/lorengordon/cfn"},"payload":{"ref":"makeguac-fixfonts","ref_type":"branch","pusher_type":"user"},"public":true,"created_at":"2015-09-29T16:58:33Z"},{"id":"3191471068","type":"MemberEvent","actor":{"id":9492187,"login":"snapswerve","gravatar_id":"","url":"https://api.github.com/users/snapswerve","avatar_url":"https://avatars.githubusercontent.com/u/9492187?"},"repo":{"id":43324126,"name":"snapswerve/sblanding","url":"https://api.github.com/repos/snapswerve/sblanding"},"payload":{"member":{"login":"caitlin-mohnike","id":5912515,"avatar_url":"https://avatars.githubusercontent.com/u/5912515?v=3","gravatar_id":"","url":"https://api.github.com/users/caitlin-mohnike","html_url":"https://github.com/caitlin-mohnike","followers_url":"https://api.github.com/users/caitlin-mohnike/followers","following_url":"https://api.github.com/users/caitlin-mohnike/following{/other_user}","gists_url":"https://api.github.com/users/caitlin-mohnike/gists{/gist_id}","starred_url":"https://api.github.com/users/caitlin-mohnike/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/caitlin-mohnike/subscriptions","organizations_url":"https://api.github.com/users/caitlin-mohnike/orgs","repos_url":"https://api.github.com/users/caitlin-mohnike/repos","events_url":"https://api.github.com/users/caitlin-mohnike/events{/privacy}","received_events_url":"https://api.github.com/users/caitlin-mohnike/received_events","type":"User","site_admin":false},"action":"added"},"public":true,"created_at":"2015-09-29T16:58:33Z"},{"id":"3191471067","type":"PullRequestEvent","actor":{"id":319055,"login":"fofr","gravatar_id":"","url":"https://api.github.com/users/fofr","avatar_url":"https://avatars.githubusercontent.com/u/319055?"},"repo":{"id":1599151,"name":"alphagov/static","url":"https://api.github.com/repos/alphagov/static"},"payload":{"action":"closed","number":657,"pull_request":{"url":"https://api.github.com/repos/alphagov/static/pulls/657","id":45918079,"html_url":"https://github.com/alphagov/static/pull/657","diff_url":"https://github ...

# %%
import requests
payload = {'key1': 'value1', 'key2': 'value2'}
r = requests.post("http://httpbin.org/post", data=payload) 
print(r.text)
r.url # note that the payload hasn't been dropped in to the url.
# Out:
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "key1": "value1",
#     "key2": "value2"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "23",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.7.0 CPython/3.5.0 Linux/3.19.0-28-generic"
#   },
#   "json": null,
#   "origin": "38.100.211.46",
#   "url": "http://httpbin.org/post"
# }
# 'http://httpbin.org/post'

# %% [markdown]
# ### ```<input>```
# #### ```type```
#
# * ```<input type="text">``` or simply ```<input>``` is a standard textbox. This can also have a value attribute, which sets the initial text in the textbox.
# * ```<input type="password">``` is similar to the textbox, but the characters typed in by the user will be hidden.
# * ```<input type="checkbox">``` is a checkbox, which can be toggled on and off by the user. This can also have a checked attribute (```<input type="checkbox" checked>``` - the attribute doesn’t require a value), and makes the initial state of the check box to be switched on, as it were.
# * ```<input type="radio">``` is similar to a checkbox, but the user can only select one radio button in a group. This can also have a checked attribute.
# * ```<input type="submit">``` is a button that when selected will submit the form. You can control the text that appears on the submit button with the value attribute, for example ```<input type="submit" value="Ooo. Look. Text on a button. Wow">```.
#
# <input type="submit" value="Ooo. Look. Text on a button. Wow">

# %% [markdown]
# #### ```name````
# #### ```value```
#
# ### ```<textarea>``
# * ```<textarea rows="5" cols="20">A big load of text</textarea>```

# %% [markdown]
# <textarea rows="5" cols="20">A big load of text</textarea>

# %% [markdown]
# ### ```<select>```
# ```
# <select>
#     <option>Option 1</option>
#     <option>Option 2</option>
#     <option value="third option">Option 3</option>
# </select>
# ```
# <select>
#     <option>Option 1</option>
#     <option>Option 2</option>
#     <option value="third option">Option 3</option>
# </select>
#
# ### Names

# %% [markdown]
# <form action="processingscript.py" method="post">
# <p>Name:</p>
#     <p><input type="text" name="name" value="Your name"></p>
#
#     <p>Comments: </p>
#     <p><textarea name="comments" rows="5" cols="20">Your comments</textarea></p>
#
#     <p>Are you:</p>
#     <p><input type="radio" name="areyou" value="male"> Male</p>
#     <p><input type="radio" name="areyou" value="female"> Female</p>
#     <p><input type="radio" name="areyou" value="chipmunk"> A chipmunk</p>
#     <p><input type="radio" name="areyou" value="vorgonthedarklord"> asdfjkl</p>
#
# </form>

# %% [markdown]
# # Now a quick detour to the developer tools
#
# ## I would suggest looking at [chrome dev tools](https://developers.google.com/web/tools/setup/workspace/setup-devtools), they're nifty
#
# ## Also, look at [this chrome guide](https://developers.google.com/web/tools/setup/workspace/setup-editor?hl=en) to setting up your environment (they recommend getting sublime)

# %% [markdown]
# # CSS
#
# ## Why CSS?
#
# http://www.csszengarden.com/
#
# ## Three types of CSS
#
# * Internal
# * Embedded
# * External
#
# In general don't do the first two.
#
# ## External
#
# To add an external stylesheet to your html insert the following into the head
# ```
# <link rel="stylesheet" href="style.css">
# ```
# Eg.
#
# ```
# <!DOCTYPE html>
# <html>
# <head>
#     <title>CSS Example</title>
#     <link rel="stylesheet" href="style.css">
# ```
#
# ## CSS Anatomy
# ### Selectors, properties, and values
#
# ```
# body {
#     font-size: 14px;
#     color: navy;
# }
# ```
#
# ## Colors
#
# * red
# * rgb(255,0,0) # Where did these numbers come from?
# * rgb(100%,0%,0%)
# * #ff0000
# * #f00
#
# Check out [Adobe color wheel](https://color.adobe.com/create/color-wheel) for a sweet color tool.

# %% [markdown]
# Demo: https://jsfiddle.net/p6mmct3z/
#
# Demo with some css: https://jsfiddle.net/p6mmct3z/2/

# %% [markdown]
# # Challenges
#
# Work up to challenge 6:
# https://en.wikiversity.org/wiki/Web_Design/CSS_challenges
#
# # Uber Challenge! (to be turned in)
#
# ## Recreate this website (I put it on slack)
# ![this website](./examples/taste.png)
